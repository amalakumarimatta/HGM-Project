# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/YueyueZhu/HGM.git
# %cd HGM
# Out:
# Cloning into 'HGM'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 71 (delta 27), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (71/71), 337.38 KiB | 3.88 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /kaggle/working/HGM

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install timm opencv-python tqdm scipy
# !pip install ninja cmake packaging setuptools wheel
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !pip install dynamic-network-architectures
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.0 MB/s eta 0:00:00
# ...
#   Created wheel for dynamic-network-architectures: filename=dynamic_network_architectures-0.4.3-py3-none-any.whl size=39033 sha256=2d8dc4bea2934ad5c5f57b6d246ac2440221fde003750e3393e0745d4ad31d28
#   Stored in directory: /root/.cache/pip/wheels/07/d9/72/fcdaffb6f05e32a67776f0038c21f3f8849aba27432aab9365
# Successfully built dynamic-network-architectures
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.25
#     Uninstalling timm-1.0.25:
#       Successfully uninstalled timm-1.0.25
# ...

# %%
# !pip install mamba-ssm --no-build-isolation --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 MB 262.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 237.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.8/260.8 kB 394.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 262.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 316.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 380.2 MB/s eta 0:00:00
# ...
#   Created wheel for mamba-ssm: filename=mamba_ssm-2.3.2.post1-cp312-cp312-linux_x86_64.whl size=322288410 sha256=7a67070c1e7e99c95abd1319623f044e8a1b3fb46f774bfdea949f0a4fc79638
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cfrs4b8c/wheels/da/67/03/99148d6eeaa4ec2855d71295ac83bcbc8ba7b41a2982992c63
# Successfully built mamba-ssm
# ...

# %%
# !python MyTest.py
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/HGM/lib/pvtv2.py:376: UserWarning: Overwriting pvt_v2_b2 in registry with lib.pvtv2.pvt_v2_b2. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# Traceback (most recent call last):
#   File "/kaggle/working/HGM/MyTest.py", line 9, in <module>
#     from lib.pvt import HGM
#   File "/kaggle/working/HGM/lib/pvt.py", line 12, in <module>
# ...

# %%
# !pip install torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.4 MB/s eta 0:00:00
# ...

# %%
# !python MyTest.py
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/HGM/lib/pvtv2.py:376: UserWarning: Overwriting pvt_v2_b2 in registry with lib.pvtv2.pvt_v2_b2. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# /kaggle/working/HGM/lib/Decoder.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)
# ...

# %%
# !mkdir -p data

# %%
# !ls /kaggle/input/datasets/amalakumarimatta/hgm-weights
# Out:
# best_parameter_HGM.pth

# %%
# !mkdir -p data
# !cp /kaggle/input/datasets/amalakumarimatta/hgm-weights/best_parameter_HGM.pth data/

# %%
# %cd /kaggle/working/HGM
# !python MyTest.py
# Out:
# /kaggle/working/HGM
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/HGM/lib/pvtv2.py:376: UserWarning: Overwriting pvt_v2_b2 in registry with lib.pvtv2.pvt_v2_b2. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# /kaggle/working/HGM/lib/Decoder.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !ls /kaggle/input
# Out:
# datasets

# %%
# !mkdir -p data
# !unzip /kaggle/input/datasets/amalakumarimatta/testdataset/TestDataset.zip -d data/
# Out:
# unzip:  cannot find or open /kaggle/input/datasets/amalakumarimatta/testdataset/TestDataset.zip, /kaggle/input/datasets/amalakumarimatta/testdataset/TestDataset.zip.zip or /kaggle/input/datasets/amalakumarimatta/testdataset/TestDataset.zip.ZIP.

# %%
# !ls /kaggle/input/datasets/amalakumarimatta/testdataset
# Out:
# TestDataset

# %%
# !mkdir -p data
# !cp -r /kaggle/input/datasets/amalakumarimatta/testdataset/TestDataset data/

# %%
# !ls data/TestDataset/CVC-300/images
# Out:
# 149.png  156.png  163.png  170.png  177.png  184.png  191.png  198.png	205.png
# 150.png  157.png  164.png  171.png  178.png  185.png  192.png  199.png	206.png
# 151.png  158.png  165.png  172.png  179.png  186.png  193.png  200.png	207.png
# 152.png  159.png  166.png  173.png  180.png  187.png  194.png  201.png	208.png
# 153.png  160.png  167.png  174.png  181.png  188.png  195.png  202.png
# 154.png  161.png  168.png  175.png  182.png  189.png  196.png  203.png
# 155.png  162.png  169.png  176.png  183.png  190.png  197.png  204.png

# %%
# %cd /kaggle/working/HGM
# !python MyTest.py
# Out:
# /kaggle/working/HGM
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/HGM/lib/pvtv2.py:376: UserWarning: Overwriting pvt_v2_b2 in registry with lib.pvtv2.pvt_v2_b2. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# /kaggle/working/HGM/lib/Decoder.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !find . -type d | grep result
# Out:
# ./data/results
# ./data/results/CVC-300_HGM

# %%
# !ls ./results/CVC-300
# Out:
# ls: cannot access './results/CVC-300': No such file or directory

# %%
# !find . -type d
# Out:
# .
# ./imgs
# ./.git
# ./.git/refs
# ./.git/refs/tags
# ./.git/refs/remotes
# ./.git/refs/remotes/origin
# ./.git/refs/heads
# ./.git/logs
# ./.git/logs/refs
# ./.git/logs/refs/remotes
# ./.git/logs/refs/remotes/origin
# ./.git/logs/refs/heads
# ./.git/info
# ./.git/hooks
# ./.git/objects
# ./.git/objects/pack
# ./.git/objects/info
# ./.git/branches
# ./lib
# ./lib/__pycache__
# ./utils
# ./utils/__pycache__
# ./data
# ./data/TestDataset
# ./data/TestDataset/CVC-ClinicDB
# ./data/TestDataset/CVC-ClinicDB/images
# ./data/TestDataset/CVC-ClinicDB/masks
# ./data/TestDataset/CVC-ColonDB
# ./data/TestDataset/CVC-ColonDB/images
# ./data/TestDataset/CVC-ColonDB/masks
# ./data/TestDataset/ETIS-LaribPolypDB
# ./data/TestDataset/ETIS-LaribPolypDB/images
# ./data/TestDataset/ETIS-LaribPolypDB/masks
# ./data/TestDataset/CVC-300
# ./data/TestDataset/CVC-300/images
# ./data/TestDataset/CVC-300/masks
# ./data/TestDataset/Kvasir
# ./data/TestDataset/Kvasir/images
# ./data/TestDataset/Kvasir/masks
# ...

# %%
# !ls /data/results/CVC-300_HGM
# Out:
# ls: cannot access '/data/results/CVC-300_HGM': No such file or directory

# %%
# !ls ./data/results/CVC-300_HGM
# Out:
# 149.png  156.png  163.png  170.png  177.png  184.png  191.png  198.png	205.png
# 150.png  157.png  164.png  171.png  178.png  185.png  192.png  199.png	206.png
# 151.png  158.png  165.png  172.png  179.png  186.png  193.png  200.png	207.png
# 152.png  159.png  166.png  173.png  180.png  187.png  194.png  201.png	208.png
# 153.png  160.png  167.png  174.png  181.png  188.png  195.png  202.png
# 154.png  161.png  168.png  175.png  182.png  189.png  196.png  203.png
# 155.png  162.png  169.png  176.png  183.png  190.png  197.png  204.png

# %%
from IPython.display import Image, display
display(Image(filename='./data/results/CVC-300_HGM/150.png'))

# %%
# !zip -r results.zip ./data/results/CVC-300_HGM
# Out:
#   adding: data/results/CVC-300_HGM/ (stored 0%)
#   adding: data/results/CVC-300_HGM/162.png (deflated 25%)
#   adding: data/results/CVC-300_HGM/156.png (deflated 25%)
#   adding: data/results/CVC-300_HGM/198.png (deflated 25%)
#   adding: data/results/CVC-300_HGM/193.png (deflated 15%)
#   adding: data/results/CVC-300_HGM/157.png (deflated 24%)
#   adding: data/results/CVC-300_HGM/197.png (deflated 13%)
#   adding: data/results/CVC-300_HGM/180.png (deflated 15%)
#   adding: data/results/CVC-300_HGM/165.png (deflated 17%)
#   adding: data/results/CVC-300_HGM/149.png (deflated 9%)
#   adding: data/results/CVC-300_HGM/176.png (deflated 15%)
#   adding: data/results/CVC-300_HGM/167.png (deflated 20%)
#   adding: data/results/CVC-300_HGM/184.png (deflated 22%)
#   adding: data/results/CVC-300_HGM/169.png (deflated 19%)
#   adding: data/results/CVC-300_HGM/189.png (deflated 24%)
#   adding: data/results/CVC-300_HGM/174.png (deflated 20%)
# ...
